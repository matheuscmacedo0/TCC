# %% [markdown]
# # Knowledge Discovery in Databases
# ## Fase de seleção dos dados

# %% [markdown]
# Nesta fase foram analisados, discutidos e selecionados os atributos que são mais relevantes e tendem a gerar respostas mais confiáveis na fase de Mineração de Dados.

# %%
import pandas as pd

# %%
df = pd.read_csv('alunos_categoria_administrativa.csv', sep='|')

# %% [markdown]
# ### Filtrando os alunos cujo a categoria administrativa do curso seja 'Pública Estadual'

# %%
df.to_csv('alunos_categoria_administrativa_PV.csv', sep=';', index=None)

# %%
dfAlunos1
# Out:
#           TP_CATEGORIA_ADMINISTRATIVA  TP_ORGANIZACAO_ACADEMICA  TP_TURNO  \
# 233257                              2                         1       4.0
# 233258                              2                         1       4.0
# 233259                              2                         1       4.0
# 233260                              2                         1       4.0
# 233261                              2                         1       4.0
# 233262                              2                         1       4.0
# 233263                              2                         1       4.0
# 233264                              2                         1       4.0
# 233265                              2                         1       4.0
# 233266                              2                         1       4.0
# 233267                              2                         1       4.0
# 233268                              2                         1       4.0
# ...
